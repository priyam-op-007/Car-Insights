# %%
import pandas as pd

# %%
indian_cars = pd.read_csv(r"C:\Users\priya\Downloads\car make data\cars_ds_final.csv")

# %%
indian_cars.head()
# Out:
#    Unnamed: 0  Make      Model  Variant Ex-Showroom_Price Displacement  \
# 0           0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc
# 1           1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc
# 2           2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc
# 3           3  Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc
# 4           4  Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc
#
#    Cylinders  Valves_Per_Cylinder              Drivetrain  \
# 0        2.0                  2.0  RWD (Rear Wheel Drive)
# 1        2.0                  2.0  RWD (Rear Wheel Drive)
# 2        2.0                  2.0  RWD (Rear Wheel Drive)
# 3        2.0                  2.0  RWD (Rear Wheel Drive)
# 4        2.0                  2.0  RWD (Rear Wheel Drive)
#
#   Cylinder_Configuration  ... Leather_Wrapped_Steering Automatic_Headlamps  \
# 0                In-line  ...                      NaN                 NaN
# ...

# %%
indian_cars.shape
# Out:
# (1276, 141)

# %%
indian_cars.dtypes
# Out:
# Unnamed: 0             int64
# Make                  object
# Model                 object
# Variant               object
# Ex-Showroom_Price     object
#                       ...
# USB_Ports            float64
# Heads-Up_Display      object
# Welcome_Lights        object
# Battery               object
# Electric_Range        object
# Length: 141, dtype: object

# %%
import numpy as np

# %%
indian_cars.replace("?",np.nan,inplace = True)

# %%
missing_data = indian_cars.isnull()

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print(missing_data[column].value_counts())
    print("")
# Out:
# Unnamed: 0
# False    1276
# Name: Unnamed: 0, dtype: int64
#
# Make
# False    1201
# True       75
# Name: Make, dtype: int64
#
# Model
# False    1276
# Name: Model, dtype: int64
#
# Variant
# False    1276
# Name: Variant, dtype: int64
#
# Ex-Showroom_Price
# False    1276
# Name: Ex-Showroom_Price, dtype: int64
#
# Displacement
# False    1264
# True       12
# Name: Displacement, dtype: int64
#
# Cylinders
# False    1210
# True       66
# Name: Cylinders, dtype: int64
#
# Valves_Per_Cylinder
# False    1174
# True      102
# Name: Valves_Per_Cylinder, dtype: int64
#
# Drivetrain
# False    1269
# True        7
# Name: Drivetrain, dtype: int64
#
# Cylinder_Configuration
# False    1263
# True       13
# Name: Cylinder_Configuration, dtype: int64
#
# Emission_Norm
# False    1265
# True       11
# Name: Emission_Norm, dtype: int64
#
# Engine_Location
# False    1233
# True       43
# Name: Engine_Location, dtype: int64
#
# Fuel_System
# False    1268
# True        8
# ...

# %%
indian_cars.dropna(subset = ["City_Mileage"], axis = 0, inplace = True)

# %%
indian_cars.shape
# Out:
# (721, 141)

# %%
indian_cars.dropna(subset = ["Make"], axis = 0, inplace = True)

# %%
indian_cars.shape
# Out:
# (671, 141)

# %%
indian_cars["Displacement"].dtype
# Out:
# dtype('O')

# %%
indian_cars['Displacement'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')

# %%
indian_cars['Displacement']
# Out:
# 0        624
# 1        624
# 3        624
# 4        624
# 5        624
#         ...
# 1271    1498
# 1272    1498
# 1273    1497
# 1274    1497
# 1275    3200
# Name: Displacement, Length: 671, dtype: object

# %%
avg_displacement = indian_cars["Displacement"].astype("float").mean(axis=0)
indian_cars["Displacement"].replace(np.nan,avg_displacement,inplace=True)

# %%
indian_cars["Displacement"].astype("float")
# Out:
# 0        624.0
# 1        624.0
# 3        624.0
# 4        624.0
# 5        624.0
#          ...
# 1271    1498.0
# 1272    1498.0
# 1273    1497.0
# 1274    1497.0
# 1275    3200.0
# Name: Displacement, Length: 671, dtype: float64

# %%
indian_cars["Displacement"].astype("float").mean()
# Out:
# 1840.1479820627803

# %%
indian_cars["Cylinders"]
# Out:
# 0       2.0
# 1       2.0
# 3       2.0
# 4       2.0
# 5       2.0
#        ...
# 1271    4.0
# 1272    4.0
# 1273    4.0
# 1274    4.0
# 1275    4.0
# Name: Cylinders, Length: 671, dtype: float64

# %%
indian_cars["Cylinders"].value_counts()
# Out:
# 4.0     464
# 3.0     112
# 6.0      26
# 8.0      23
# 10.0     10
# 12.0      8
# 5.0       6
# 2.0       5
# Name: Cylinders, dtype: int64

# %%
indian_cars["Cylinders"].replace(np.nan,4.0,inplace=True)

# %%
indian_cars["Valves_Per_Cylinder"].value_counts()
# Out:
# 4.0    616
# 2.0     41
# 8.0      2
# 3.0      2
# Name: Valves_Per_Cylinder, dtype: int64

# %%
indian_cars["Valves_Per_Cylinder"].replace(np.nan,4.0,inplace=True)

# %%
indian_cars["Drivetrain"].value_counts()
# Out:
# FWD (Front Wheel Drive)    479
# RWD (Rear Wheel Drive)      96
# AWD (All Wheel Drive)       67
# 4WD                         27
# Name: Drivetrain, dtype: int64

# %%
indian_cars["Drivetrain"].replace(np.nan,"FWD (Front Wheel Drive)",inplace=True)

# %%
indian_cars["Cylinder_Configuration"].value_counts()
# Out:
# In-line    598
# V           59
# Flat         4
# W            3
# Name: Cylinder_Configuration, dtype: int64

# %%
indian_cars["Cylinder_Configuration"].replace(np.nan,"In-line",inplace=True)

# %%
indian_cars["Emission_Norm"].value_counts()
# Out:
# BS IV     574
# BS 6       70
# BS VI      13
# BS III      9
# Name: Emission_Norm, dtype: int64

# %%
indian_cars["Emission_Norm"].replace(np.nan,"BS IV",inplace=True)

# %%
indian_cars["Fuel_System"].value_counts()
# Out:
# Injection    666
# PGM - Fi       1
# Name: Fuel_System, dtype: int64

# %%
indian_cars["Fuel_System"].replace(np.nan,"Injection",inplace=True)

# %%
indian_cars['Fuel_Tank_Capacity'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')
avg_fuel = indian_cars["Fuel_Tank_Capacity"].astype("float").mean(axis=0)
indian_cars["Fuel_Tank_Capacity"].replace(np.nan,avg_fuel,inplace=True)

# %%
avg_fuel
# Out:
# 58.19384615384615

# %%
indian_cars["Fuel_Tank_Capacity"]
# Out:
# 0       24
# 1       24
# 3       24
# 4       24
# 5       24
#         ..
# 1271    40
# 1272    40
# 1273    40
# 1274    40
# 1275    88
# Name: Fuel_Tank_Capacity, Length: 671, dtype: object

# %%
indian_cars['Width'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')
avg_width = indian_cars["Width"].astype("float").mean(axis=0)
indian_cars["Width"].replace(np.nan,avg_fuel,inplace=True)

# %%
avg_width
# Out:
# 1779.0272727272727

# %%
indian_cars['Highway_Mileage'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')
avg_width = indian_cars["Highway_Mileage"].astype("float").mean(axis=0)
indian_cars["Highway_Mileage"].replace(np.nan,avg_fuel,inplace=True)

# %%
indian_cars['ARAI_Certified_Mileage'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')
avg_width = indian_cars["ARAI_Certified_Mileage"].astype("float").mean(axis=0)
indian_cars["ARAI_Certified_Mileage"].replace(np.nan,avg_fuel,inplace=True)

# %%
indian_cars["Kerb_Weight"]
# Out:
# 0        660 kg
# 1        725 kg
# 3        725 kg
# 4        725 kg
# 5        710 kg
#          ...
# 1271    1170 kg
# 1272    1175 kg
# 1273    1107 kg
# 1274    1080 kg
# 1275    2335 kg
# Name: Kerb_Weight, Length: 671, dtype: object

# %%
indian_cars['Kerb_Weight'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')
avg_width = indian_cars["Kerb_Weight"].astype("float").mean(axis=0)
indian_cars["Kerb_Weight"].replace(np.nan,avg_fuel,inplace=True)

# %%
indian_cars["Gears"].value_counts()
# Out:
# 5    383
# 6    128
# 7     64
# 8     50
# 4      9
# 9      3
# Name: Gears, dtype: int64

# %%
indian_cars["Gears"].replace(np.nan,'5',inplace=True)

# %%
indian_cars['Ground_Clearance'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')
avg_width = indian_cars["Ground_Clearance"].astype("float").mean(axis=0)
indian_cars["Ground_Clearance"].replace(np.nan,avg_fuel,inplace=True)

# %%
indian_cars["Seating_Capacity"].value_counts()
# Out:
# 5.0    446
# 7.0    113
# 4.0     37
# 2.0     24
# 9.0     19
# 6.0     17
# 8.0     13
# Name: Seating_Capacity, dtype: int64

# %%
indian_cars["Seating_Capacity"].replace(np.nan,5.0,inplace=True)

# %%
indian_cars["Engine_Type"].value_counts()
# Out:
# Revotron 1.2 L, BS6 Engine    6
# Name: Engine_Type, dtype: int64

# %%
indian_cars["Wheels_Size"].value_counts()
# Out:
# 185/60R15    54
# 205/65R16    27
# 215/65R16    22
# 185/65R14    22
# 185/65R15    21
#              ..
# 245/75R15     1
# 255/60R18     1
# 155/85R18     1
# 21 Inch       1
# 18            1
# Name: Wheels_Size, Length: 134, dtype: int64

# %%
indian_cars["Wheels_Size"].replace(np.nan,'185/60R15',inplace=True)

# %%
indian_cars.drop(['Engine_Location','ARAI_Certified_Mileage_for_CNG','Front_Brakes','Rear_Brakes','Front_Suspension','Rear_Suspension','Front_Track','Rear_Track','Front_Tyre_&_Rim','Rear_Tyre_&_Rim','Power_Steering','Power_Windows','Power_Seats','Keyless_Entry','Torque','Odometer','Speedometer','Tachometer','Tripmeter'],inplace=True,axis=1)

# %%
indian_cars.drop(['Seating_Capacity','Seats_Material','Type','Wheelbase','Wheels_Size','Start_/_Stop_Button','12v_Power_Outlet','Audiosystem','Aux-in_Compatibility','Average_Fuel_Consumption','Basic_Warranty','Bluetooth','Boot-lid_Opener','Boot_Space','CD_/_MP3_/_DVD_Player','Central_Locking','Child_Safety_Locks','Clock','Cup_Holders','Distance_to_Empty','Door_Pockets','Engine_Malfunction_Light','Extended_Warranty','FM_Radio','Fuel-lid_Opener','Fuel_Gauge','Handbrake','Instrument_Console','Low_Fuel_Warning','Minimum_Turning_Radius','Multifunction_Display','Sun_Visor','Third_Row_AC_Vents','Ventilation_System','Auto-Dimming_Rear-View_Mirror','Hill_Assist','Gear_Indicator','3_Point_Seat-Belt_in_Middle_Rear_Seat','Ambient_Lightning','Cargo/Boot_Lights','Drive_Modes','Engine_Immobilizer','High_Speed_Alert_System','Lane_Watch_Camera/_Side_Mirror_Camera'],inplace=True,axis=1)

# %%
indian_cars.drop(['Passenger_Side_Seat-Belt_Reminder','Seat_Back_Pockets','Voice_Recognition','Walk_Away_Auto_Car_Lock','ABS_(Anti-lock_Braking_System)','Headlight_Reminder','Adjustable_Headrests','Gross_Vehicle_Weight','Airbags','Door_Ajar_Warning','EBD_(Electronic_Brake-force_Distribution)','Fasten_Seat_Belt_Warning','Gear_Shift_Reminder','Number_of_Airbags','Compression_Ratio','Adjustable_Steering_Column','Other_Specs','Other_specs','Parking_Assistance','Key_Off_Reminder','USB_Compatibility','Android_Auto','Apple_CarPlay','Cigarette_Lighter','Infotainment_Screen','Multifunction_Steering_Wheel','Average_Speed','EBA_(Electronic_Brake_Assist)','Seat_Height_Adjustment','Navigation_System','Second_Row_AC_Vents','Tyre_Pressure_Monitoring_System','Rear_Center_Armrest','iPod_Compatibility','ESP_(Electronic_Stability_Program)','Cooled_Glove_Box','Recommended_Tyre_Pressure'],inplace=True,axis=1)

# %%
indian_cars.drop(['Heated_Seats','Turbocharger','ISOFIX_(Child-Seat_Mount)','Rain_Sensing_Wipers','Paddle_Shifters','Leather_Wrapped_Steering','Automatic_Headlamps','Engine_Type','ASR_/_Traction_Control','Cruise_Control','USB_Ports','Heads-Up_Display','Welcome_Lights','Battery','Electric_Range'],inplace=True,axis=1)

# %%
indian_cars.dtypes
# Out:
# Unnamed: 0                  int64
# Make                       object
# Model                      object
# Variant                    object
# Ex-Showroom_Price          object
# Displacement               object
# Cylinders                 float64
# Valves_Per_Cylinder       float64
# Drivetrain                 object
# Cylinder_Configuration     object
# Emission_Norm              object
# Fuel_System                object
# Fuel_Tank_Capacity         object
# Fuel_Type                  object
# Height                     object
# Length                     object
# Width                      object
# Body_Type                  object
# Doors                     float64
# City_Mileage               object
# Highway_Mileage            object
# ARAI_Certified_Mileage     object
# Kerb_Weight                object
# Gears                      object
# Ground_Clearance           object
# Power                      object
# dtype: object

# %%
indian_cars.head()
# Out:
#    Unnamed: 0  Make      Model Variant Ex-Showroom_Price Displacement  \
# 0           0  Tata  Nano Genx      Xt      Rs. 2,92,667          624
# 1           1  Tata  Nano Genx      Xe      Rs. 2,36,447          624
# 3           3  Tata  Nano Genx     Xta      Rs. 3,34,768          624
# 4           4  Tata  Nano Genx      Xm      Rs. 2,72,223          624
# 5           5  Tata  Nano Genx     Xma      Rs. 3,14,815          624
#
#    Cylinders  Valves_Per_Cylinder              Drivetrain  \
# 0        2.0                  2.0  RWD (Rear Wheel Drive)
# 1        2.0                  2.0  RWD (Rear Wheel Drive)
# 3        2.0                  2.0  RWD (Rear Wheel Drive)
# 4        2.0                  2.0  RWD (Rear Wheel Drive)
# 5        2.0                  2.0  RWD (Rear Wheel Drive)
#
#   Cylinder_Configuration  ... Width  Body_Type Doors    City_Mileage  \
# 0                In-line  ...  1750  Hatchback   5.0  ?23.6 km/litre
# ...

# %%
indian_cars['Ex-Showroom_Price'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')

# %%
indian_cars['City_Mileage'] = indian_cars['City_Mileage'].map(lambda x: str(x)[:-4])

# %%
indian_cars['City_Mileage'] = indian_cars['City_Mileage'].str.replace(',','.')

# %%
indian_cars['City_Mileage'] = indian_cars['City_Mileage'].str.replace('-12.7','')
# Out:
# C:\Users\priya\AppData\Local\Temp\ipykernel_76684\3555076114.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   indian_cars['City_Mileage'] = indian_cars['City_Mileage'].str.replace('-12.7','')

# %%
indian_cars.dtypes
# Out:
# Unnamed: 0                  int64
# Make                       object
# Model                      object
# Variant                    object
# Ex-Showroom_Price          object
# Displacement               object
# Cylinders                 float64
# Valves_Per_Cylinder       float64
# Drivetrain                 object
# Cylinder_Configuration     object
# Emission_Norm              object
# Fuel_System                object
# Fuel_Tank_Capacity         object
# Fuel_Type                  object
# Height                     object
# Length                     object
# Width                      object
# Body_Type                  object
# Doors                     float64
# City_Mileage               object
# Highway_Mileage            object
# ARAI_Certified_Mileage     object
# Kerb_Weight                object
# Gears                      object
# Ground_Clearance           object
# Power                      object
# dtype: object

# %%
indian_cars[["Displacement","Ex-Showroom_Price","Width"]] = indian_cars[["Displacement","Ex-Showroom_Price","Width"]].astype("float")

# %%
indian_cars["Gears"]
# Out:
# 0       4
# 1       4
# 3       5
# 4       4
# 5       5
#        ..
# 1271    6
# 1272    6
# 1273    5
# 1274    5
# 1275    5
# Name: Gears, Length: 671, dtype: object

# %%
indian_cars['Length'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')

# %%
indian_cars['Power'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')

# %%
indian_cars['Height'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')

# %%
indian_cars[["Fuel_Tank_Capacity","Height","Length"]] = indian_cars[["Fuel_Tank_Capacity","Height","Length"]].astype("float")

# %%
indian_cars[["Kerb_Weight","Gears","Ground_Clearance"]] = indian_cars[["Kerb_Weight","Gears","Ground_Clearance"]].astype("float")

# %%
indian_cars[["Power","Highway_Mileage"]] = indian_cars[["Power","Highway_Mileage"]].astype("float")

# %%
indian_cars.dtypes
# Out:
# Unnamed: 0                  int64
# Make                       object
# Model                      object
# Variant                    object
# Ex-Showroom_Price         float64
# Displacement              float64
# Cylinders                 float64
# Valves_Per_Cylinder       float64
# Drivetrain                 object
# Cylinder_Configuration     object
# Emission_Norm              object
# Fuel_System                object
# Fuel_Tank_Capacity        float64
# Fuel_Type                  object
# Height                    float64
# Length                    float64
# Width                     float64
# Body_Type                  object
# Doors                     float64
# City_Mileage              float64
# Highway_Mileage           float64
# ARAI_Certified_Mileage    float64
# Kerb_Weight               float64
# Gears                     float64
# Ground_Clearance          float64
# Power                     float64
# dtype: object

# %%
indian_cars[["City_Mileage"]] = indian_cars[["City_Mileage"]].astype("float")

# %%
indian_cars[["Ground_Clearance"]] = indian_cars[["Ground_Clearance"]].astype("float")

# %%
indian_cars["Ex-Showroom_Price"].max()
# Out:
# 53210327.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
# create a new column indicating whether the price is under 1000000
indian_cars.loc[indian_cars['Ex-Showroom_Price'] < 1000000, 'price_category'] = 'under 1000000'
# group the data by brand name and price category, and count the number of occurrences
grouped_data = indian_cars.groupby(['Make', 'price_category']).size().reset_index(name='count')
# filter the data for cars under 1000000
filtered_data = grouped_data[grouped_data['price_category'] == 'under 1000000'][['Make', 'count']]
# create a bar graph of the filtered data
filtered_data.plot.bar(x='Make', y='count')
# add labels and title to the graph
plt.xlabel("Brand")
plt.ylabel("Number of Cars")
plt.title("Number of Cars under Rs 10,00,000 by Brand")

# display the graph
plt.show()

# %%
# create a new column indicating whether the price is above 1000000 and under 5000000
indian_cars.loc[(indian_cars['Ex-Showroom_Price'] > 1000000) & (indian_cars['Ex-Showroom_Price'] < 5000000), 'price_category'] = 'above 1000000 and under 5000000'

# group the data by brand name and price category, and count the number of occurrences
grouped_data = indian_cars.groupby(['Make', 'price_category']).size().reset_index(name='count')

# filter the data for cars above 1000000 and under 5000000
filtered_data = grouped_data[grouped_data['price_category'] == 'above 1000000 and under 5000000'][['Make', 'count']]

# create a bar graph of the filtered data
filtered_data.plot.bar(x='Make', y='count')

# add labels and title to the graph
plt.xlabel("Brand")
plt.ylabel("Number of Cars")
plt.title("Number of Cars above Rs 10,00,000 and under Rs 50,00,000 by Brand")

# display the graph
plt.show()

# %%
indian_cars.dtypes
# Out:
# Unnamed: 0                  int64
# Make                       object
# Model                      object
# Variant                    object
# Ex-Showroom_Price         float64
# Displacement              float64
# Cylinders                 float64
# Valves_Per_Cylinder       float64
# Drivetrain                 object
# Cylinder_Configuration     object
# Emission_Norm              object
# Fuel_System                object
# Fuel_Tank_Capacity        float64
# Fuel_Type                  object
# Height                    float64
# Length                    float64
# Width                     float64
# Body_Type                  object
# Doors                     float64
# City_Mileage              float64
# Highway_Mileage           float64
# ARAI_Certified_Mileage    float64
# Kerb_Weight               float64
# Gears                     float64
# Ground_Clearance          float64
# Power                     float64
# price_category             object
# dtype: object

# %%
# create a new column indicating whether the price is above 5000000 and under 10000000
indian_cars.loc[(indian_cars['Ex-Showroom_Price'] > 5000000) & (indian_cars['Ex-Showroom_Price'] < 10000000), 'price_category'] = 'above 5000000 and under 10000000'

# group the data by brand name and price category, and count the number of occurrences
grouped_data = indian_cars.groupby(['Make', 'price_category']).size().reset_index(name='count')

# filter the data for cars above 5000000 and under 10000000
filtered_data = grouped_data[grouped_data['price_category'] == 'above 5000000 and under 10000000'][['Make', 'count']]

# create a bar graph of the filtered data
filtered_data.plot.bar(x='Make', y='count')

# add labels and title to the graph
plt.xlabel("Brand")
plt.ylabel("Number of Cars")
plt.title("Number of Cars above Rs 50,00,000 and under Rs 1,00,00,000 by Brand")

# display the graph
plt.show()

# %%
indian_cars["Ex-Showroom_Price"].max()
# Out:
# 53210327.0

# %%
# create a new column indicating whether the price is above 10000000
indian_cars.loc[indian_cars['Ex-Showroom_Price'] > 10000000, 'price_category'] = 'above 10000000'

# group the data by brand name and price category, and count the number of occurrences
grouped_data = indian_cars.groupby(['Make', 'price_category']).size().reset_index(name='count')

# filter the data for cars above 10000000
filtered_data = grouped_data[grouped_data['price_category'] == 'above 10000000'][['Make', 'count']]

# create a bar graph of the filtered data
filtered_data.plot.bar(x='Make', y='count')

# add labels and title to the graph
plt.xlabel("Brand")
plt.ylabel("Number of Cars")
plt.title("Number of Cars above Rs 1,00,00,000 by Brand")

# display the graph
plt.show()

# %%
indian_cars["City_Mileage"].max()
indian_cars['City_Mileage'] = indian_cars['City_Mileage'].replace(2.0,6.0)

# %%
indian_cars["City_Mileage"].mean()
# Out:
# 15.679120715350214

# %%
plt.scatter(indian_cars["Displacement"], indian_cars["City_Mileage"])
plt.xlabel("Engine Displacement")
plt.ylabel("City Mileage")
plt.title("Relationship between Engine Displacement and City Mileage")
plt.show()

# %%
indian_cars["City_Mileage"].min()
# Out:
# 3.0

# %%
indian_cars[indian_cars['City_Mileage'] < 4]
# Out:
#       Unnamed: 0         Make       Model           Variant  \
# 872          872      Ferrari     488 Gtb               Std
# 873          873      Ferrari     488 Gtb            Spider
# 876          876  Lamborghini   Aventador          Lp 700-4
# 877          877  Lamborghini   Aventador  Lp700-4 Roadster
# 878          878  Lamborghini   Aventador                 S
# 1172        1172      Ferrari  458 Spider                V8
#
#       Ex-Showroom_Price  Displacement  Cylinders  Valves_Per_Cylinder  \
# 872          36761413.0        3902.0        8.0                  4.0
# 873          39319552.0        3902.0        8.0                  4.0
# 876          47893943.0        6498.0       12.0                  4.0
# 877          53210327.0        6498.0       12.0                  4.0
# 878          47467700.0        6498.0       12.0                  4.0
# 1172         43367500.0        3902.0        8.0                  4.0
#
# ...

# %%
plt.scatter(indian_cars["Cylinders"], indian_cars["City_Mileage"])
plt.xlabel("Number of Cylinders")
plt.ylabel("City Mileage")
plt.title("Relationship between number of Cylinders and City Mileage")
plt.show()

# %%
import seaborn as sns
sns.regplot(x="Displacement",y="City_Mileage",data=indian_cars)
plt.xlabel("Engine Displacement")
plt.ylabel("City Mileage")
plt.title("Relationship between Engine Displacement and City Mileage")
plt.show()

# %%
sns.regplot(x="Cylinders",y="City_Mileage",data=indian_cars)
plt.xlabel("Number of Cylinders")
plt.ylabel("City Mileage")
plt.title("Relationship between number of Cylinders and City Mileage")
plt.show()

# %%
import plotly.express as px
# group the data by brand name and average the city mileage
grouped_data = indian_cars.groupby(['Make'])['City_Mileage'].mean().reset_index()

# create a radial column chart of the grouped data
fig = px.bar_polar(grouped_data, r='City_Mileage', theta='Make',
                    width=1500, height=650)
fig.update_layout(title='City Mileage by Brand')

# display the chart
fig.show()

# %%
sns.regplot(x="Ex-Showroom_Price",y="City_Mileage",data=indian_cars)
plt.xlabel("Ex-Showroom_Price")
plt.ylabel("City Mileage")
plt.title("Relationship between number of Price and City Mileage")
plt.show()

# %%
grouped_data = indian_cars.groupby(['Make'])['Ex-Showroom_Price'].mean()

# create a bar graph of the grouped data
grouped_data.plot.bar()

# add labels and title to the graph
plt.xlabel("Brand")
plt.ylabel("Average Price")
plt.title("Average Price by Brand")

# display the graph
plt.show()

# %%
indian_cars.dtypes
# Out:
# Unnamed: 0                  int64
# Make                       object
# Model                      object
# Variant                    object
# Ex-Showroom_Price         float64
# Displacement              float64
# Cylinders                 float64
# Valves_Per_Cylinder       float64
# Drivetrain                 object
# Cylinder_Configuration     object
# Emission_Norm              object
# Fuel_System                object
# Fuel_Tank_Capacity        float64
# Fuel_Type                  object
# Height                    float64
# Length                    float64
# Width                     float64
# Body_Type                  object
# Doors                     float64
# City_Mileage              float64
# Highway_Mileage           float64
# ARAI_Certified_Mileage    float64
# Kerb_Weight               float64
# Gears                     float64
# Ground_Clearance          float64
# Power                     float64
# price_category             object
# dtype: object

# %%
# get the count of each body type
body_type_count = indian_cars['Body_Type'].value_counts().reset_index()

# create a radial column chart of the body type count
fig = px.bar_polar(body_type_count, r='Body_Type', theta='index',
                    width=600, height=400)
fig.update_layout(title='Body Type Count')

# display the chart
fig.show()

# %%
# get the count of each fuel type
body_type_count = indian_cars['Fuel_Type'].value_counts().reset_index()

# create a radial column chart of the body type count
fig = px.bar_polar(body_type_count, r='Fuel_Type', theta='index',
                    width=800, height=400)
fig.update_layout(title='Fuel type Count')

# display the chart
fig.show()

# %%
grouped_data = indian_cars.groupby(['Gears'])['City_Mileage'].mean()

# create a bar graph of the grouped data
grouped_data.plot.bar()

# add labels and title to the graph
plt.xlabel("Gears")
plt.ylabel("Average Mileage")
plt.title("Average Mileage by Number of Gears")

# display the graph
plt.show()

# %%
sns.regplot(x="Gears",y="City_Mileage",data=indian_cars)
plt.xlabel("Gears")
plt.ylabel("City Mileage")
plt.title("Relationship between number of Gears and City Mileage")
plt.show()

# %%
sns.regplot(x="Cylinders",y="City_Mileage",data=indian_cars)
plt.xlabel("Cylinders")
plt.ylabel("City Mileage")
plt.title("Relationship between number of Cylinders and City Mileage")
plt.show()

# %%
gears_count = indian_cars.groupby(['Gears'])['Make'].count()
gears_count = gears_count/gears_count.sum()
plt.pie(gears_count, labels=gears_count.index, autopct='%1.1f%%')
plt.title("Percentage of Cars with each Number of Gears")
plt.show()

# %%
sns.regplot(x="Highway_Mileage",y="City_Mileage",data=indian_cars)
plt.xlabel("Ex-Showroom_Price")
plt.ylabel("City Mileage")
plt.title("Relationship between number of Price and City Mileage")
plt.show()

# %%
correlation = indian_cars[['Kerb_Weight','Power','Gears','Ground_Clearance']].corr()

# print the correlation matrix
print(correlation)
# Out:
#                   Kerb_Weight     Power     Gears  Ground_Clearance
# Kerb_Weight          1.000000  0.155385  0.310072          0.242682
# Power                0.155385  1.000000  0.130724          0.442045
# Gears                0.310072  0.130724  1.000000          0.188503
# Ground_Clearance     0.242682  0.442045  0.188503          1.000000

# %%
# create boxplots for the dimensions by car make
indian_cars.boxplot(column=['Height','Length','Width'], by='Make')

# add labels and title to the plots
plt.xlabel("Car Make")
plt.ylabel("Dimensions (cm)")
plt.title("Distribution of Dimensions for Each Car Brand")

# display the plots
plt.show()
